# %%
# PARETO DISTRIBUTION : IT IS ALSO KNOWN AS 80:20 RATIO DISTRIBUTION .
# 80:20 RATIO DISTRIBUTION MEANS 20% FACTORS CAUSE 80% OUTCOME OR RESULT .
# random.pareto() IS USED FOR PARETO DISTRIBUTION .
# random.pareto() HAS 2 ARGUMENTS : a() AND size() .
# a() MEANS SHAPE OF DISTRIBUTION .

# GENERATE A PARETO DISTRIBUTION OF SHAPE 2 AND SIZE 4*6 .

from numpy import random
e = random.pareto ( a=2 , size=(4,6) )
print(e)
# Out:
# [[4.58875386e-01 5.07848746e-01 6.89312722e-01 3.23366491e-01
#   2.47488306e-01 6.86472313e-01]
#  [7.30202058e-01 4.27247936e-01 4.22659230e-02 6.95962046e-01
#   4.68066998e+00 4.83085926e-01]
#  [1.05535044e-01 7.39735971e-01 6.86826538e-02 2.21717956e+00
#   1.72383852e+00 4.25234153e-02]
#  [2.24668047e-02 5.01880643e-01 5.09068030e-01 2.06341898e-01
#   3.41144076e-04 7.53931234e-01]]

# %%
# GENERATE A PARETO DISTRIBUTION OF SHAPE 8 AND SIZE 4*6 .

from numpy import random
f = random.pareto ( a=8 , size=(4,6) )
print(f)
# Out:
# [[0.07974987 0.17647894 0.09321578 0.36229882 0.64100439 0.00334081]
#  [0.02858987 0.08884946 0.20977404 0.15075163 0.07983144 0.08303611]
#  [0.16222183 0.02512228 0.02656557 0.0039774  0.0713009  0.07669262]
#  [0.22834149 0.03946187 0.11082299 0.39285384 0.13467906 0.04084425]]

# %%
# VISUALIZATION OF PARETO DISTRIBUTION .

from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns

g = random.pareto ( a=2 , size=800 )
sns.distplot ( g , kde=False )
plt.show()
# Out:
# C:\Users\ARPIT-MIMANI\AppData\Local\Temp\ipykernel_9556\1607363522.py:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot ( g , kde=False )

# %%
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns

h = random.pareto ( a=4 , size=800 )
sns.distplot ( h , kde=False )
plt.show()
# Out:
# C:\Users\ARPIT-MIMANI\AppData\Local\Temp\ipykernel_9556\1372374318.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot ( h , kde=False )

# %%
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns

k = random.pareto ( a=4 , size=400 )
sns.distplot ( k , kde=False )
plt.show()
# Out:
# C:\Users\ARPIT-MIMANI\AppData\Local\Temp\ipykernel_9556\3793020622.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot ( k , kde=False )

# %%
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns

l = random.pareto ( a=1 , size=400 )
sns.distplot ( l , kde=False )
plt.show()
# Out:
# C:\Users\ARPIT-MIMANI\AppData\Local\Temp\ipykernel_9556\4244823311.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot ( l , kde=False )
